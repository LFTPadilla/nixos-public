# %%
light.turn_on(entity_id="light.bathroom_light", brightness=30, rgb_color=[255, 0, 0])

# %%
from datetime import datetime, time

now_time = datetime.now().time()
time_20_00 = datetime.strptime("11:00", "%H:%M").time()
print(now_time >= time_20_00)
# Out:
# True
